# %% [markdown]
#                                          Basics of Flask:

# %% [markdown]
#       1. Create a Flask app that displays "Hello, World!" on the homepage.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.29.19:5000
# Press CTRL+C to quit

# %% [markdown]
# 3. Develop a Flask app that uses URL parameters to display dynamic content.

# %%
#importing the flask Module
from flask import Flask

# Flask constructor takes the name of
# current module (__name__) as argument
app = Flask(__name__)

@app.route('/')
# ‘/’ URL is bound with hello_world() function.
def home():
	return 'You are at home page.'

@app.route('/allow')
def allow():
	return 'You have been allowed to enter.'

@app.route('/disallow')
def disallow():
	return 'You have not been allowed to enter.'

# main driver function
if __name__ == '__main__':
	# run() method of Flask class runs the application
	# on the local development server.
	app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.29.19:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Dec/2023 07:41:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 07:41:22] "GET /favicon.ico HTTP/1.1" 404 -
# 192.168.29.19 - - [06/Dec/2023 07:41:30] "GET / HTTP/1.1" 200 -
# 192.168.29.19 - - [06/Dec/2023 07:41:30] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Dec/2023 07:41:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 07:42:09] "GET /allow HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 07:42:21] "GET /disallow HTTP/1.1" 200 -

# %% [markdown]
# 4. Create a Flask app with a form that accepts user input and displays it.

# %%
# importing Flask and other modules
from flask import Flask, request, render_template 

# Flask constructor
app = Flask(__name__) 

# A decorator used to tell the application
# which URL is associated function
@app.route('/', methods =["POST", "GET"])
def form():
	if request.method == "POST":
	   # getting input with name = fname in HTML form
	    first_name = request.form.get('fname')
	   # getting input with name = lname in HTML form 
	    last_name = request.form.get("lname") 
	    return "Your name is " + first_name + " " + last_name
	return render_template("form.html")

if __name__=='__main__':
   app.run(host="0.0.0.0",port=5004)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5004
#  * Running on http://192.168.29.19:5004
# Press CTRL+C to quit
# 192.168.29.19 - - [06/Dec/2023 15:02:39] "GET / HTTP/1.1" 200 -
# 192.168.29.19 - - [06/Dec/2023 15:02:45] "POST / HTTP/1.1" 200 -

# %% [markdown]
# 5. Implement user sessions in a Flask app to store and display user-specific data.

# %%
from flask import Flask, render_template, redirect, request, session
# The Session instance is not used for direct access, you should always use flask.session
from flask_session import Session

app = Flask(__name__)
app.config["SESSION_PERMANENT"] = False
app.config["SESSION_TYPE"] = "filesystem"
Session(app)


@app.route("/")
def index():
	if not session.get("name"):
		return redirect("/login")
	return render_template('index1.html')


@app.route("/login", methods=["POST", "GET"])
def login():
	if request.method == "POST":
		session["name"] = request.form.get("name")
		return redirect("/")
	return render_template("login.html")


@app.route("/logout")
def logout():
	session["name"] = None
	return redirect("/")


if __name__ == "__main__":
	app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Dec/2023 15:28:07] "GET / HTTP/1.1" 302 -
# 127.0.0.1 - - [06/Dec/2023 15:28:07] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 15:28:07] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Dec/2023 15:28:14] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [06/Dec/2023 15:28:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 15:28:35] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 15:28:39] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [06/Dec/2023 15:28:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 15:28:41] "GET /logout HTTP/1.1" 302 -
# 127.0.0.1 - - [06/Dec/2023 15:28:41] "GET / HTTP/1.1" 302 -
# 127.0.0.1 - - [06/Dec/2023 15:28:41] "GET /login HTTP/1.1" 200 -

# %% [markdown]
#                                            Intermediate Flask Topics:

# %% [markdown]
# 6. Build a Flask app that allows users to upload files and display them on the website.

# %%
from flask import Flask, render_template, request 
from werkzeug.utils import secure_filename
app = Flask(__name__)

@app.route('/upload')  
def upload_file():
   return render_template('upload.html')

@app.route('/upload_post', methods = ['POST'])
def upload_post():
   if request.method == 'POST':
        f = request.files['file']
        f.save(secure_filename(f.filename))
        return 'file uploaded successfully'
   pass

if __name__ == '__main__':
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.3:5000
# Press CTRL+C to quit
# 192.168.1.3 - - [06/Dec/2023 22:09:42] "GET / HTTP/1.1" 404 -
# 192.168.1.3 - - [06/Dec/2023 22:09:58] "GET / HTTP/1.1" 404 -
# 192.168.1.3 - - [06/Dec/2023 22:09:58] "GET /favicon.ico HTTP/1.1" 404 -
# 192.168.1.3 - - [06/Dec/2023 22:10:08] "GET /add HTTP/1.1" 404 -
# 192.168.1.3 - - [06/Dec/2023 22:10:18] "GET /upload HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 22:10:25] "POST /upload_post HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 22:10:25] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# 7. Integrate a SQLite database with Flask to perform CRUD operations on a list of items.

# %%
from flask import * 
import sqlite3  
  
app = Flask(__name__)  
 
@app.route("/")  
def index():  
    return render_template("index2.html");  
 
@app.route("/add")  
def add():  
    return render_template("add.html")  
 
@app.route("/savedetails",methods = ["POST","GET"])  
def saveDetails():  
    msg = "msg"  
    if request.method == "POST":  
        try:  
            name = request.form["name"]  
            email = request.form["email"]  
            address = request.form["address"]  
            with sqlite3.connect("database.db") as con:  
                cur = con.cursor()  
                cur.execute("INSERT into Employees (name, email, address) values (?,?,?)",(name,email,address))  
                con.commit()  
                msg = "Employee successfully Added"  
        except:  
            con.rollback()  
            msg = "We can not add the employee to the list"  
        finally:  
            return render_template("success.html",msg = msg)  
            con.close()  
 
@app.route("/view")  
def view():  
    con = sqlite3.connect("database.db")  
    con.row_factory = sqlite3.Row  
    cur = con.cursor()  
    cur.execute("select * from Employees")  
    rows = cur.fetchall()  
    return render_template("view.html",rows = rows)  
 
 
@app.route("/delete")  
def delete():  
    return render_template("delete.html")  
 
@app.route("/deleterecord",methods = ["POST"])  
def deleterecord():  
    id = request.form["id"]  
    with sqlite3.connect("employee.db") as con:  
        try:  
            cur = con.cursor()  
            cur.execute("delete from Employees where id = ?",id)  
            msg = "record successfully deleted"  
        except:  
            msg = "can't be deleted"  
        finally:  
            return render_template("delete_record.html",msg = msg)  
  
if __name__ == "__main__":  
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.29.19:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [09/Dec/2023 07:38:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:38:33] "GET /add HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:38:37] "POST /savedetails HTTP/1.1" 200 -
# [2023-12-09 07:38:38,579] ERROR in app: Exception on /view [GET]
# Traceback (most recent call last):
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\flask\app.py", line 1455, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\flask\app.py", line 869, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\flask\app.py", line 867, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\flask\app.py", line 852, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Temp\ipykernel_5112\3117819873.py", line 39, in view
#     cur.execute("select * from Employees")
# sqlite3.DatabaseError: file is not a database
# 127.0.0.1 - - [09/Dec/2023 07:38:38] "GET /view HTTP/1.1" 500 -

# %% [markdown]
# 8. Implement user authentication and registration in a Flask app using Flask-Login.

# %%
from flask import Flask, render_template, request
from pymongo import MongoClient

app = Flask(__name__)

# Connect to MongoDB
client = MongoClient('mongodb+srv://bhavesh:bhavesh@cluster0.t0d1cat.mongodb.net/?retryWrites=true&w=majority')
db = client['client_database']  # Replace 'client_database' with your database name
collection = db['users']  # Replace 'users' with your collection name

@app.route("/")
def login():
    return render_template('login2.html')

@app.route("/register")
def register():
    return render_template('register.html')

@app.route("/home")
def home():
    return render_template('home1.html')

@app.route("/signup", methods=['POST'])
def signup():
    email = request.form.get('email')
    password = request.form.get('password')

    # Check if user already exists
    if collection.find_one({'email': email}):
        return "User already exists. Please sign in."

    # Insert new user into MongoDB
    user = {'email': email, 'password': password}
    collection.insert_one(user)

    return "Registration successful. Please sign in."

@app.route("/login_validation", methods=['POST'])
def login1():
    email = request.form.get('email')
    password = request.form.get('password')
    client = MongoClient('mongodb+srv://bhavesh:bhavesh@cluster0.t0d1cat.mongodb.net/?retryWrites=true&w=majority')
    db = client['client_database']  # Replace 'client_database' with your database name
    collection = db['users'] 

    # Check if user exists and password matches
    user = collection.find_one({'email': email, 'password': password})
    print(user)
    if user:
        # Valid credentials, redirect to the home page or perform desired actions
        return render_template('home1.html', user=user)
    else:
        # Invalid credentials, show error message and prompt to sign up
        return "User not found. Please sign up."

if __name__ == "__main__":
    app.run(host="127.0.0.1", port=8000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8000
# Press CTRL+C to quit

# %% [markdown]
# 9. Create a RESTful API using Flask to perform CRUD operations on resources like books or movies.

# %%
# using flask_restful 
from flask import Flask, jsonify, request 
from flask_restful import Resource, Api 

# creating the flask app 
app = Flask(__name__) 
# creating an API object 
api = Api(app) 

# making a class for a particular resource 
# the get, post methods correspond to get and post requests 
# they are automatically mapped by flask_restful. 
# other methods include put, delete, etc. 
class Hello(Resource): 

	# corresponds to the GET request. 
	# this function is called whenever there 
	# is a GET request for this resource 
	def get(self): 

		return jsonify({'message': 'hello world'}) 

	# Corresponds to POST request 
	def post(self): 
		
		data = request.get_json()	 # status code 
		return jsonify({'data': data}), 201


# another resource to calculate the square of a number 
class Square(Resource): 

	def get(self, num): 

		return jsonify({'square': num**2}) 


# adding the defined resources along with their corresponding urls 
api.add_resource(Hello, '/') 
api.add_resource(Square, '/square/<int:num>') 


# driver function 
if __name__ == '__main__': 

	app.run(host="0.0.0.0",port=5004)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5004
#  * Running on http://192.168.29.19:5004
# Press CTRL+C to quit
# 127.0.0.1 - - [08/Dec/2023 17:25:24] "GET / HTTP/1.1" 200 -

# %% [markdown]
# 10. Design a Flask app with proper error handling for 404 and 500 errors.

# %%
from flask import Flask, render_template, request, abort
import werkzeug

app = Flask(__name__)

@app.route("/")
def index():
    return render_template("index.html")

@app.route("/simulate404")
def simulate404():
    abort(404)
    return render_template("more.html")

@app.route("/simulate500")
def simulate500():
    abort(500)
    return render_template("more.html")

@app.errorhandler(404)
def not_found_error(error):
    return render_template('404.html'), 404

@app.errorhandler(werkzeug.exceptions.HTTPException)
def internal_error(error):
    return render_template('500.html'), 500

if __name__ == "__main__":
    app.run(host="0.0.0.0",port=5008)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5008
#  * Running on http://192.168.29.19:5008
# Press CTRL+C to quit

# %% [markdown]
#                                                  Real-time Development:

# %% [markdown]
# 11. Create a real-time chat application using Flask-SocketIO.

# %%
from flask import Flask, render_template, request, redirect, url_for
from flask_socketio import SocketIO, join_room, leave_room

app = Flask(__name__)
socketio = SocketIO(app)


@app.route('/')
def home():
    return render_template("index4.html")


@app.route('/chat')
def chat():
    username = request.args.get('username')
    room = request.args.get('room')

    if username and room:
        return render_template('chat.html', username=username, room=room)
    else:
        return redirect(url_for('home'))


@socketio.on('send_message')
def handle_send_message_event(data):
    app.logger.info("{} has sent message to the room {}: {}".format(data['username'],
                                                                    data['room'],
                                                                    data['message']))
    socketio.emit('receive_message', data, room=data['room'])


@socketio.on('join_room')
def handle_join_room_event(data):
    app.logger.info("{} has joined the room {}".format(data['username'], data['room']))
    join_room(data['room'])
    socketio.emit('join_room_announcement', data, room=data['room'])


@socketio.on('leave_room')
def handle_leave_room_event(data):
    app.logger.info("{} has left the room {}".format(data['username'], data['room']))
    leave_room(data['room'])
    socketio.emit('leave_room_announcement', data, room=data['room'])


if __name__ == '__main__':
    app.run(host='127.0.0.1', port=5000, debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %% [markdown]
# 12. Build a Flask app that updates data in real-time using WebSocket connections.

# %%
from flask import Flask, render_template, request
from flask_socketio import SocketIO
from random import random
from threading import Lock
from datetime import datetime

"""
Background Thread
"""
thread = None
thread_lock = Lock()

app = Flask(__name__)
app.config['SECRET_KEY'] = 'donsky!'
socketio = SocketIO(app, cors_allowed_origins='*')

"""
Get current date time
"""
def get_current_datetime():
    now = datetime.now()
    return now.strftime("%m/%d/%Y %H:%M:%S")

"""
Generate random sequence of dummy sensor values and send it to our clients
"""
def background_thread():
    print("Generating random sensor values")
    while True:
        dummy_sensor_value = round(random() * 100, 3)
        socketio.emit('updateSensorData', {'value': dummy_sensor_value, "date": get_current_datetime()})
        socketio.sleep(1)

"""
Serve root index file
"""
@app.route('/')
def index():
    return render_template('index8.html')

"""
Decorator for connect
"""
@socketio.on('/connect')
def connect():
    global thread
    print('Client connected')

    global thread
    with thread_lock:
        if thread is None:
            thread = socketio.start_background_task(background_thread)

"""
Decorator for disconnect
"""
@socketio.on('disconnect')
def disconnect():
    print('Client disconnected', request.sid)

if __name__ == "__main__":
    app.run(host="127.0.0.1", port=5000)
    # socketio.run(app)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMa3 HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "POST /socket.io/?EIO=4&transport=polling&t=OnCMMca&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMcb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMcw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMdL&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMdQ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMdb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMdj&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMdu&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMeC&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMeQ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMee&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMfH&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMfu&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMg9&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMgH&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMgi&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMgp&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMg-&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMhB&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMhX&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMhe&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMi1&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMiM&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMib&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMim&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMiu&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMj4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMjD&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMjO&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMjp&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMjv&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMk0&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMk7&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMkD&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMkO&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMkT&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMkd&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMkj&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMku&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMlE&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMlP&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMlV&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMle&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMm9&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:57] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMmF&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMmN&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMmU&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMmb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMmk&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMm-&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMn4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMnE&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMnK&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMnV&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMnb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMnm&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMnr&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMo0&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMoB&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMoJ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMoS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMoi&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMov&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMp4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMpT&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMpd&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMpl&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMpv&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMq2&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMqB&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMqL&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMqS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMqm&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMr7&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMrD&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMrO&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMrl&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMry&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMsO&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMsU&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMsl&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMsw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMt1&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMtD&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMtS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMtX&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMtf&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMtm&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMtv&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMu2&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMuD&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMuJ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMuS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMuZ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMuq&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMuy&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMv4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMvK&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMvS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMva&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMvh&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMvr&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMvy&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMw5&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMwM&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMwS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMwd&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMwj&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMws&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMx4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMxA&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMxJ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMxQ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMxW&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMxg&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMy1&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMyH&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMyZ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMyx&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMzA&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMzG&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMzO&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMzV&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMMzb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM-D&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM-I&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM-Q&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM-X&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM-d&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM-n&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM-v&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM_E&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM_N&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:58] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM_l&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMM_t&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN0K&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN1L&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN1T&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN1c&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN1j&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN1s&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN1z&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN27&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN2F&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN2P&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN2e&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN2l&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN2v&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN31&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN3B&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN3I&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN3S&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN3Z&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN3i&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN3p&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN3y&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN44&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN4E&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN4L&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN4U&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN4b&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN4-&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN53&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN5E&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN5L&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN5T&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN5a&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN5r&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN5x&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN64&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN6A&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN6J&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN6P&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN6Z&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN6g&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN6s&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN6z&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN7B&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN7M&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN7T&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN7d&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN7s&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN85&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN8C&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN8N&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN8T&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN8d&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN8j&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN8w&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN8_&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN98&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN9F&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN9N&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN9a&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMN9y&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNA2&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNAB&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNAg&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNAm&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNAt&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNA-&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNB3&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNBE&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNBK&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNBT&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNBZ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNBz&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNCL&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNCT&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNCn&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNCt&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMND0&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNDN&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNDY&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNDe&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNDl&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNDu&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNE5&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNEB&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNEL&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNER&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNEZ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNEg&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNEm&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNEv&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNE_&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNFI&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:42:59] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNFT&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNFc&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNFs&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNGg&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNGn&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNGx&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNHC&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNHH&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNHO&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNHW&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNHb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNHm&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNHr&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNH_&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNI5&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNIE&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNIK&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNIU&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNIb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNIq&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNIx&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNJ3&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNJ9&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNJI&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNJn&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNJs&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNJx&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNK4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNKA&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNKI&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNKQ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNKa&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNKg&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNKp&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNKw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNL1&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNL9&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNLF&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNLd&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNLr&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNLz&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNM8&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNMG&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNMS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNMc&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNMm&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNN9&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNNF&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNNN&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNNV&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNNx&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNO0&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNO6&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNOE&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNOJ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNOS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNOZ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNOg&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNOp&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNOz&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNP4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNPB&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNPa&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNPg&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNPp&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNPu&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNQ2&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNQ7&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNQI&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNQO&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNQZ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNQf&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNQr&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNQx&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNR4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNRA&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNRa&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNRg&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNRm&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNRv&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNR_&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNSO&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNST&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNSb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNSi&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNSn&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNSy&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNT2&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNTP&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNTV&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNTc&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNTj&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNTp&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNTy&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNU3&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNUC&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNUH&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNUS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNUY&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNUg&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNUn&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNUs&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:00] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNV0&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNV5&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNVF&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNVL&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNVW&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNVb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNVl&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNVr&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNVz&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNW4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNWA&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNWK&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNWQ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNWZ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNWe&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNWp&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNWw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNX4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNXB&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNXW&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNXe&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNXj&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNXt&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNXz&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNY6&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNYC&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNYM&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNYS&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNYb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNYj&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNYr&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNY_&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNZA&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNZF&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNZe&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNZj&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNZp&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNZ-&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNaA&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:01] "GET /socket.io/?EIO=4&transport=polling&t=OnCMNaG&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# ...
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOTw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOU0&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOUA&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOUI&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOUU&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOUZ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOUw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOV2&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOV9&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOVN&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOVd&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOVo&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOVv&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOW7&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOWI&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOWc&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOWl&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOWs&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOW_&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOX9&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOXN&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOXV&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOXs&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOXx&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOY6&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOYC&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOYc&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOYj&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOYw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOY_&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOZB&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOZM&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOZd&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOa_&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMObF&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMObM&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMObU&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMObb&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMObq&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMObw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOc4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOcC&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOcZ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOce&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOco&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOcu&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOd4&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOdJ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOdQ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOdc&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOdq&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOdw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOe5&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOeB&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOeM&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOef&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOeq&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOf0&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOfL&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOfw&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOg5&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOgF&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOgX&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOgp&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOh1&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOhA&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOhV&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOha&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOho&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOi1&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOiI&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOiQ&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOim&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOis&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOj0&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:05] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOj5&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOjF&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOjP&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOjl&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOjx&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOkG&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOkO&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOkY&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOke&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOkr&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOlI&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOlj&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOls&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOl_&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOmT&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=polling&t=OnCMOma&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 07:43:06] "GET /socket.io/?EIO=4&transport=websocket&sid=VHsaW-PapzienN_FAAAA HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\engineio\async_drivers\_websocket_wsgi.py", line 26, in send
#     return self.ws.send(message)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\simple_websocket\ws.py", line 78, in send
#     raise ConnectionClosed(self.close_reason, self.close_message)
# simple_websocket.errors.ConnectionClosed: Connection closed: 1005
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\werkzeug\serving.py", line 362, in run_wsgi
#     execute(self.server.app)
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\werkzeug\serving.py", line 323, in execute
#     application_iter = app(environ, start_response)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\flask\app.py", line 1478, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\flask_socketio\__init__.py", line 43, in __call__
#     return super(_SocketIOMiddleware, self).__call__(environ,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\engineio\middleware.py", line 63, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\socketio\server.py", line 428, in handle_request
#     return self.eio.handle_request(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\engineio\server.py", line 271, in handle_request
#     packets = socket.handle_get_request(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\engineio\socket.py", line 90, in handle_get_request
#     return getattr(self, '_upgrade_' + transport)(environ,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\engineio\socket.py", line 146, in _upgrade_websocket
#     ws(environ, start_response)
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\engineio\async_drivers\_websocket_wsgi.py", line 15, in __call__
#     ret = self.app(self)
#           ^^^^^^^^^^^^^^
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\engineio\socket.py", line 176, in _websocket_handler
#     ws.send(packet.Packet(packet.PONG, data='probe').encode())
#   File "C:\Users\praja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\engineio\async_drivers\_websocket_wsgi.py", line 28, in send
#     raise IOError()
# OSError

# %% [markdown]
# 13. Implement notifications in a Flask app using websockets to notify users of updates.
